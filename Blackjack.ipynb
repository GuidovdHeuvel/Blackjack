# %% [markdown]
# ## Python Blackjack
# For this project you will make a Blackjack game using Python. Click <a href="https://en.wikipedia.org/wiki/Blackjack" target="_blank">here</a> to familiarize yourself with the the rules of the game. You won't be implementing every rule "down to the letter" with the game, but we will doing a simpler version of the game. This assignment will be given to further test your knowledge on object-oriented programming concepts.
#
# ### Rules:
#
# `1. ` The game will have two players: the Dealer and the Player. The game will start off with a deck of 52 cards. The 52 cards will consist of 4 different suits: Clubs, Diamonds, Hearts and Spades. For each suit, there will be cards numbered 1 through 13. <br>
# **Note: No wildcards will be used in the program**
#
# `2. ` When the game begins, the dealer will shuffle the deck of cards, making them randomized. After the dealer shuffles, it will deal the player 2 cards and will deal itself 2 cards from. The Player should be able to see both of their own cards, but should only be able to see one of the Dealer's cards.
#
# `3. ` The objective of the game is for the Player to count their cards after they're dealt. If they're not satisfied with the number, they have the ability to 'Hit'. A hit allows the dealer to deal the Player one additional card. The Player can hit as many times as they'd like as long as they don't 'Bust'. A bust is when the Player is dealt cards that total more than 21.
#
# `4. ` If the dealer deals the Player cards equal to 21 on the **first** deal, the Player wins. This is referred to as Blackjack. Blackjack is **NOT** the same as getting cards that equal up to 21 after the first deal. Blackjack can only be attained on the first deal.
#
# `5. ` The Player will never see the Dealer's hand until the Player chooses to 'stand'. A Stand is when the player tells the dealer to not deal it anymore cards. Once the player chooses to Stand, the Player and the Dealer will compare their hands. Whoever has the higher number wins. Keep in mind that the Dealer can also bust.

# %%
    suits = ["♠" , "♣", "♥", "♦"]
    ranks = list(range(1, 14))
    deck = [(ranks, suits) for rank in ranks for suit in suits]

# %%
from IPython.display import clear_output 
import random
class Deck:
    def __init__(self):
        self.suits = ["♠" , "♣", "♥", "♦"]
        self.ranks = list(range(1, 14))
        self.deck = [(rank, suit) for rank in ranks for suit in suits]
    
    def shuffle_deck(self):
        random.shuffle(self.deck)
    
    def deal_card(self):
#         c = deck.pop(random.randint(0,len(self.deck)-1))
        return self.deck.pop()

    def clear_hand(self):
        Dealer.dealer_hand = []
        Dealer.dealer_hand_value = 0
        Human.hand = []
        Human.hand_value = 0

class Player:
    pass

class Dealer(Player):
    def __init__(self, dealer_hand=None, dealer_hand_value=0):
        self.dealer_hand = []
        self.dealer_hand_value = dealer_hand_value
        
    def dealer_play(self, deck):
        while self.dealer_hand_value < 17:
            self.dealer_hit(deck)
        print(self.dealer_hand)    
        print(self.dealer_hand_value)
        
    def dealer_start(self, deck):
        self.dealer_hand = []
        self.dealer_hand_value = 0
        dealer_card = deck.deal_card()
        self.dealer_hand.append(dealer_card)
        self.dealer_hand_value += dealer_card[0]
        print(self.dealer_hand)
        print(self.dealer_hand_value)
        
    def dealer_hit(self, deck):
        dealer_card = deck.deal_card()
        self.dealer_hand.append(dealer_card)
        self.dealer_hand_value += dealer_card[0]  
        
class Human(Player): 
    def __init__(self, hand=None, hand_value=0):
        self.hand = []
        self.hand_value = hand_value
 
    def human_start(self, deck):
        self.hand = []
        self.hand_value = 0
        card = deck.deal_card()
        self.hand.append(card)
        self.hand_value += card[0]
        card = deck.deal_card()
        self.hand.append(card)
        self.hand_value += card[0]    
        print(self.hand)
        print(self.hand_value)
        
    def human_hit(self, deck):
        card = deck.deal_card()
        self.hand.append(card)
        self.hand_value += card[0]
        print(self.hand)
        print(self.hand_value)
    
class Game:
    def __init__(self, dealer, human, deck):
        self.dealer = dealer
        self.human = human
        self.deck = deck
        
    def game_start(self):
        self.human = Human.human_start()
        self.dealer = Dealer.dealer_start()
        
    def show_instructions():
        print(f"blablabla hoop instructies over hoe je het spel moet spelen blablabla")
        
       
    @classmethod
    def run(self):
        deck = Deck()
        human1 = Human()
        dealer1 = Dealer()
        game = Game(deck, human1, dealer1)
        
        game_over = False
        while not game_over:
            ask = input("Welcome to Blackjack! You know the rules! Press 'ENTER' to continue or 'Q' to quit. ").lower()
            if ask == 'q':
                game_over = True
            else:
                deck.shuffle_deck()
                print("Dealer dealing...")
                human1.human_start(deck)
                dealer1.dealer_start(deck)
                flag = False
                while not flag:
                    if human1.hand_value == 21:
                        print("Blackjack! You won!")
                        flag = True
                    elif human1.hand_value > 21:
                        print("Bust!")
                        flag = True
                    elif human1.hand_value != 21:
                        flag = False
                        while not flag:
                            speel = input("Would you like to hit or stand? ").lower()
                            if speel == "hit":
                                human1.human_hit(deck)
                                if human1.hand_value > 21:
                                    print("Bust!")
                                    flag = True
                                if human1.hand_value == 21:
                                    flag = True
                            if speel == "stand":
                                dealer1.dealer_play(deck)
                                if dealer1.dealer_hand_value > 21:
                                    print("Dealer bust, you win!")
                                    flag = True
                                elif dealer1.dealer_hand_value > human1.hand_value:
                                    print("Dealer win!")
                                    flag = True
                                elif dealer1.dealer_hand_value < human1.hand_value:
                                    print("You win!")
                                    flag = True

# %%
Game.run()
# Out:
# Welcome to Blackjack! You know the rules! Press 'ENTER' to continue or 'Q' to quit.
# Dealer dealing...
# [(8, '♣'), (4, '♦')]
# 12
# [(12, '♦')]
# 12
# Would you like to hit or stand? hit
# [(8, '♣'), (4, '♦'), (4, '♥')]
# 16
# Would you like to hit or stand? hit
# [(8, '♣'), (4, '♦'), (4, '♥'), (1, '♦')]
# 17
# Would you like to hit or stand? stand
# [(12, '♦'), (8, '♦')]
# 20
# Dealer win!
# Welcome to Blackjack! You know the rules! Press 'ENTER' to continue or 'Q' to quit. q
